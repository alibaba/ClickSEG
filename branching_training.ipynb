# %%
import multiprocessing
import nvidia_smi
from os import path as osp, getcwd

# %%
# Check GPU
# !nvidia-smi -L
# Out:
# GPU 0: Tesla V100-SXM3-32GB (UUID: GPU-3f66cb17-51c3-5eaa-68ba-1d4713de8b54)

# %%
# Choose num workers based on number of available CPUs
n_workers = multiprocessing.cpu_count() - 2
n_workers
# Out:
# 94

# %%
# Choose batch size based on amount of available video memory
nvidia_smi.nvmlInit()
handle = nvidia_smi.nvmlDeviceGetHandleByIndex(0)
info = nvidia_smi.nvmlDeviceGetMemoryInfo(handle)
avail_gpu_memory = info.free
batch_size_choices = [2**n for n in range(0,10)]
batch_size_pre_alignment = (avail_gpu_memory / 10e8)*4
batch_size = [x for x in batch_size_choices if x < batch_size_pre_alignment][-1]
batch_size
# Out:
# 128

# %%
# Training config variables
dataset_path = osp.join(getcwd(), "..", "branching_retinal_mix_dataset")
train_script = osp.join(getcwd(), "train.py")
model_path = osp.join(getcwd(), "models/segformerB0_tubes.py")
pretrained_weights = osp.join(getcwd(), "pretrained/segformer_b0/last_checkpoint.pth")
exp_name = "segformerB0_tubes"

# %%
# Run training
train_args = [
    model_path,
    f"--pretrained_weights={pretrained_weights}",
    f"--dataset_path={dataset_path}",
    "--gpus=0",
    f"--workers={n_workers}",
    f"--batch-size={batch_size}",
    f"--exp-name={exp_name}",
    #"--resume-exp=000",
    #"--resume-prefix=42",
    #"--start-epoch=43"
]
execute_training_cmd = f"python {train_script} {' '.join(train_args)}"
# !{execute_training_cmd}
# Out:
# Number of GPUs: 1
# Run experiment with config:
# {   'CHECKPOINTS_PATH': PosixPath('/nfs/hpc/share/wigginno/branching/ClickSEG/experiments/segformerB0_tubes/004_segformerB0_tubes/checkpoints'),
#     'EXP_PATH': PosixPath('/nfs/hpc/share/wigginno/branching/ClickSEG/experiments/segformerB0_tubes/004_segformerB0_tubes'),
#     'LOGS_PATH': PosixPath('/nfs/hpc/share/wigginno/branching/ClickSEG/experiments/segformerB0_tubes/004_segformerB0_tubes/logs'),
#     'VIS_PATH': PosixPath('/nfs/hpc/share/wigginno/branching/ClickSEG/experiments/segformerB0_tubes/004_segformerB0_tubes/vis'),
#     'batch_size': 128,
#     'dataset_path': '/nfs/hpc/share/wigginno/branching/branching_retinal_mix_dataset',
#     'device': device(type='cuda', index=0),
#     'distributed': False,
#     'exp_name': 'segformerB0_tubes',
#     'gpu_ids': [0],
#     'gpus': '0',
#     'local_rank': 0,
#     'model_path': '/nfs/hpc/share/wigginno/branching/ClickSEG/models/segformerB0_tubes.py',
#     'multi_gpu': False,
#     'ngpus': 1,
#     'pretrained_weights': '/nfs/hpc/share/wigginno/branching/ClickSEG/pretrained/segformer_b0/last_checkpoint.pth',
#     'resume_exp': None,
#     'resume_prefix': 'latest',
#     'start_epoch': 0,
#     'temp_model_path': '',
#     'weights': None,
#     'workers': 94}
# Missing Keys:  {'block1.0.mlp.fc2.weight', 'block4.1.attn.kv.weight', 'patch_embed4.proj.bias', 'block1.0.mlp.fc1.bias', 'block3.0.norm1.weight', 'block2.1.mlp.dwconv.dwconv.bias', 'block2.0.attn.sr.weight', 'block3.0.mlp.dwconv.dwconv.bias', 'block4.1.norm2.weight', 'patch_embed3.proj.weight', 'patch_embed4.proj.weight', 'patch_embed3.norm.bias', 'block2.1.attn.proj.weight', 'block3.1.attn.norm.bias', 'block1.1.mlp.fc2.weight', 'block3.1.attn.kv.weight', 'block3.1.norm2.weight', 'block4.0.attn.kv.bias', 'block3.0.attn.kv.bias', 'block4.0.attn.q.weight', 'block1.0.attn.proj.bias', 'block3.1.attn.norm.weight', 'block1.0.attn.q.bias', 'block1.0.attn.norm.weight', 'patch_embed3.norm.weight', 'block1.1.attn.sr.weight', 'block3.0.mlp.fc2.weight', 'patch_embed2.proj.bias', 'block2.0.mlp.dwconv.dwconv.weight', 'block4.1.attn.proj.bias', 'block3.0.attn.q.weight', 'block2.0.norm2.bias', 'block1.0.attn.kv.bias', 'norm1.bias', 'block3.1.attn.kv.bias', 'block4.1.mlp.fc2.weight', 'patch_embed_side1.norm.bias', 'block4.0.mlp.fc1.bias', 'block1.1.attn.q.weight', 'block3.1.norm1.weight', 'block3.1.attn.sr.weight', 'block3.1.mlp.fc1.bias', 'patch_embed2.norm.bias', 'block2.1.norm1.bias', 'block3.1.mlp.fc2.weight', 'block2.1.norm1.weight', 'block4.0.mlp.fc1.weight', 'block3.0.norm2.weight', 'block2.1.attn.kv.weight', 'patch_embed_side1.proj.bias', 'patch_embed4.norm.bias', 'block3.1.attn.proj.weight', 'norm3.bias', 'norm3.weight', 'block4.0.norm2.weight', 'block1.0.attn.proj.weight', 'block1.1.attn.proj.weight', 'block2.0.attn.norm.weight', 'block4.1.attn.q.bias', 'block2.1.attn.q.bias', 'block3.1.attn.proj.bias', 'block1.0.attn.q.weight', 'block2.0.attn.norm.bias', 'block2.1.mlp.fc1.weight', 'patch_embed2.norm.weight', 'patch_embed_side1.proj.weight', 'block2.1.norm2.bias', 'patch_embed1.proj.bias', 'block2.0.attn.proj.weight', 'block1.0.attn.sr.bias', 'block4.0.mlp.fc2.bias', 'block4.1.attn.proj.weight', 'block1.0.attn.sr.weight', 'block4.1.norm1.bias', 'norm1.weight', 'block2.0.mlp.dwconv.dwconv.bias', 'block1.1.attn.kv.weight', 'block2.1.attn.norm.bias', 'block2.1.attn.proj.bias', 'block1.1.mlp.dwconv.dwconv.weight', 'block3.1.mlp.fc2.bias', 'norm4.bias', 'block1.0.attn.kv.weight', 'block3.0.attn.q.bias', 'block3.0.attn.kv.weight', 'block2.0.mlp.fc1.weight', 'block3.1.mlp.fc1.weight', 'block1.0.norm2.bias', 'block2.0.mlp.fc2.weight', 'block3.0.attn.sr.bias', 'block2.1.mlp.fc2.bias', 'block1.0.norm2.weight', 'block2.1.mlp.fc1.bias', 'block2.0.attn.kv.weight', 'block1.0.mlp.fc1.weight', 'block4.0.attn.proj.weight', 'block3.0.norm2.bias', 'block4.1.mlp.fc2.bias', 'block1.1.mlp.fc1.bias', 'block4.0.attn.kv.weight', 'block2.0.mlp.fc1.bias', 'block3.0.norm1.bias', 'block2.0.attn.q.weight', 'block3.0.attn.sr.weight', 'block1.1.attn.proj.bias', 'block1.1.norm1.weight', 'block4.0.attn.q.bias', 'block4.1.norm1.weight', 'block4.1.mlp.dwconv.dwconv.bias', 'block4.0.mlp.dwconv.dwconv.weight', 'block4.1.attn.kv.bias', 'block2.0.norm1.weight', 'patch_embed1.proj.weight', 'block2.1.norm2.weight', 'block1.0.mlp.fc2.bias', 'block2.1.attn.norm.weight', 'block2.1.mlp.dwconv.dwconv.weight', 'block3.0.mlp.fc1.weight', 'block4.0.mlp.fc2.weight', 'block2.0.norm2.weight', 'patch_embed1.norm.bias', 'block1.1.attn.q.bias', 'patch_embed1.norm.weight', 'block4.1.mlp.dwconv.dwconv.weight', 'block3.0.attn.norm.weight', 'block1.1.norm2.bias', 'block3.1.attn.sr.bias', 'block2.1.attn.sr.bias', 'block1.0.norm1.bias', 'block2.1.mlp.fc2.weight', 'block3.1.norm2.bias', 'block1.1.attn.sr.bias', 'block1.1.attn.norm.bias', 'block4.1.attn.q.weight', 'block4.1.norm2.bias', 'norm2.weight', 'block1.0.mlp.dwconv.dwconv.weight', 'block1.0.norm1.weight', 'block2.0.attn.kv.bias', 'block3.0.mlp.fc2.bias', 'block3.1.mlp.dwconv.dwconv.bias', 'patch_embed4.norm.weight', 'patch_embed3.proj.bias', 'patch_embed2.proj.weight', 'block1.1.norm1.bias', 'block1.1.norm2.weight', 'block2.0.attn.proj.bias', 'block2.1.attn.sr.weight', 'block4.1.mlp.fc1.weight', 'block1.0.mlp.dwconv.dwconv.bias', 'block4. ...
# Unexpected Keys:  {'config', 'state_dict'}
# cfg.dataset_path: /nfs/hpc/share/wigginno/branching/branching_retinal_mix_dataset
# Dataset of 1766 samples was loaded for training.
# Dataset of 533 samples was loaded for validation.
# /nfs/stak/users/wigginno/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py:474: UserWarning: This DataLoader will create 94 worker processes in total. Our suggested max number of worker in current system is 24, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Applied lr_mult=0.1 to "feature_extractor.backbone.patch_embed1.proj.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.patch_embed1.proj.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.patch_embed1.norm.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.patch_embed1.norm.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.patch_embed2.proj.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.patch_embed2.proj.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.patch_embed2.norm.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.patch_embed2.norm.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.patch_embed3.proj.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.patch_embed3.proj.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.patch_embed3.norm.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.patch_embed3.norm.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.patch_embed4.proj.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.patch_embed4.proj.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.patch_embed4.norm.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.patch_embed4.norm.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.patch_embed_side1.proj.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.patch_embed_side1.proj.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.patch_embed_side1.norm.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.patch_embed_side1.norm.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block1.0.norm1.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block1.0.norm1.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block1.0.attn.q.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block1.0.attn.q.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block1.0.attn.kv.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block1.0.attn.kv.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block1.0.attn.proj.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block1.0.attn.proj.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block1.0.attn.sr.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block1.0.attn.sr.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block1.0.attn.norm.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block1.0.attn.norm.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block1.0.norm2.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block1.0.norm2.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block1.0.mlp.fc1.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block1.0.mlp.fc1.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block1.0.mlp.dwconv.dwconv.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block1.0.mlp.dwconv.dwconv.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block1.0.mlp.fc2.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block1.0.mlp.fc2.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block1.1.norm1.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block1.1.norm1.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block1.1.attn.q.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block1.1.attn.q.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block1.1.attn.kv.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block1.1.attn.kv.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block1.1.attn.proj.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block1.1.attn.proj.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block1.1.attn.sr.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block1.1.attn.sr.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block1.1.attn.norm.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block1.1.attn.norm.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block1.1.norm2.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block1.1.norm2.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block1.1.mlp.fc1.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block1.1.mlp.fc1.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block1.1.mlp.dwconv.dwconv.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block1.1.mlp.dwconv.dwconv.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block1.1.mlp.fc2.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block1.1.mlp.fc2.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.norm1.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.norm1.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block2.0.norm1.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block2.0.norm1.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block2.0.attn.q.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block2.0.attn.q.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block2.0.attn.kv.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block2.0.attn.kv.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block2.0.attn.proj.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block2.0.attn.proj.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block2.0.attn.sr.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block2.0.attn.sr.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block2.0.attn.norm.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block2.0.attn.norm.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block2.0.norm2.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block2.0.norm2.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block2.0.mlp.fc1.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block2.0.mlp.fc1.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block2.0.mlp.dwconv.dwconv.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block2.0.mlp.dwconv.dwconv.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block2.0.mlp.fc2.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block2.0.mlp.fc2.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block2.1.norm1.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block2.1.norm1.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block2.1.attn.q.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block2.1.attn.q.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block2.1.attn.kv.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block2.1.attn.kv.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block2.1.attn.proj.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block2.1.attn.proj.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block2.1.attn.sr.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block2.1.attn.sr.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block2.1.attn.norm.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block2.1.attn.norm.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block2.1.norm2.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block2.1.norm2.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block2.1.mlp.fc1.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block2.1.mlp.fc1.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block2.1.mlp.dwconv.dwconv.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block2.1.mlp.dwconv.dwconv.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block2.1.mlp.fc2.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block2.1.mlp.fc2.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.norm2.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.norm2.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block3.0.norm1.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block3.0.norm1.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block3.0.attn.q.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block3.0.attn.q.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block3.0.attn.kv.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block3.0.attn.kv.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block3.0.attn.proj.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block3.0.attn.proj.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block3.0.attn.sr.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block3.0.attn.sr.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block3.0.attn.norm.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block3.0.attn.norm.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block3.0.norm2.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block3.0.norm2.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block3.0.mlp.fc1.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block3.0.mlp.fc1.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block3.0.mlp.dwconv.dwconv.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block3.0.mlp.dwconv.dwconv.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block3.0.mlp.fc2.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block3.0.mlp.fc2.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block3.1.norm1.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block3.1.norm1.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block3.1.attn.q.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block3.1.attn.q.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block3.1.attn.kv.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block3.1.attn.kv.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block3.1.attn.proj.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block3.1.attn.proj.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block3.1.attn.sr.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block3.1.attn.sr.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block3.1.attn.norm.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block3.1.attn.norm.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block3.1.norm2.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block3.1.norm2.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block3.1.mlp.fc1.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block3.1.mlp.fc1.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block3.1.mlp.dwconv.dwconv.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block3.1.mlp.dwconv.dwconv.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block3.1.mlp.fc2.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block3.1.mlp.fc2.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.norm3.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.norm3.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block4.0.norm1.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block4.0.norm1.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block4.0.attn.q.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block4.0.attn.q.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block4.0.attn.kv.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block4.0.attn.kv.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block4.0.attn.proj.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block4.0.attn.proj.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block4.0.norm2.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block4.0.norm2.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block4.0.mlp.fc1.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block4.0.mlp.fc1.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block4.0.mlp.dwconv.dwconv.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block4.0.mlp.dwconv.dwconv.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block4.0.mlp.fc2.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block4.0.mlp.fc2.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block4.1.norm1.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block4.1.norm1.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block4.1.attn.q.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block4.1.attn.q.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block4.1.attn.kv.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block4.1.attn.kv.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block4.1.attn.proj.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block4.1.attn.proj.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block4.1.norm2.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block4.1.norm2.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block4.1.mlp.fc1.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block4.1.mlp.fc1.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block4.1.mlp.dwconv.dwconv.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block4.1.mlp.dwconv.dwconv.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block4.1.mlp.fc2.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.block4.1.mlp.fc2.bias" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.norm4.weight" parameter.
# Applied lr_mult=0.1 to "feature_extractor.backbone.norm4.bias" parameter.
# SegFormerModel(
#   (maps_transform): Sequential(
#     (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (1): LeakyReLU(negative_slope=0.2)
#     (2): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (3): ScaleLayer()
#   )
#   (dist_maps_2): DistMaps()
#   (dist_maps_5): DistMaps()
#   (feature_extractor): SegFormer(
#     (backbone): mit_b0(
#       (patch_embed1): OverlapPatchEmbed(
#         (proj): Conv2d(3, 32, kernel_size=(7, 7), stride=(4, 4), padding=(3, 3))
#         (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#       )
#       (patch_embed2): OverlapPatchEmbed(
#         (proj): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#       )
#       (patch_embed3): OverlapPatchEmbed(
#         (proj): Conv2d(64, 160, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (norm): LayerNorm((160,), eps=1e-05, elementwise_affine=True)
#       )
#       (patch_embed4): OverlapPatchEmbed(
#         (proj): Conv2d(160, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       )
#       (patch_embed_side1): OverlapPatchEmbed(
#         (proj): Conv2d(3, 32, kernel_size=(7, 7), stride=(4, 4), padding=(3, 3))
#         (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#       )
#       (block1): ModuleList(
#         (0): Block(
#           (norm1): LayerNorm((32,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention(
#             (q): Linear(in_features=32, out_features=32, bias=True)
#             (kv): Linear(in_features=32, out_features=64, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=32, out_features=32, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (sr): Conv2d(32, 32, kernel_size=(8, 8), stride=(8, 8))
#             (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#           )
#           (drop_path): Identity()
#           (norm2): LayerNorm((32,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=32, out_features=128, bias=True)
#             (dwconv): DWConv(
#               (dwconv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#             )
#             (act): GELU()
#             (fc2): Linear(in_features=128, out_features=32, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (1): Block(
#           (norm1): LayerNorm((32,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention(
#             (q): Linear(in_features=32, out_features=32, bias=True)
#             (kv): Linear(in_features=32, out_features=64, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=32, out_features=32, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (sr): Conv2d(32, 32, kernel_size=(8, 8), stride=(8, 8))
#             (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#           )
#           (drop_path): DropPath()
#           (norm2): LayerNorm((32,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=32, out_features=128, bias=True)
#             (dwconv): DWConv(
#               (dwconv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#             )
#             (act): GELU()
#             (fc2): Linear(in_features=128, out_features=32, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#       )
#       (norm1): LayerNorm((32,), eps=1e-06, elementwise_affine=True)
#       (block2): ModuleList(
#         (0): Block(
#           (norm1): LayerNorm((64,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention(
#             (q): Linear(in_features=64, out_features=64, bias=True)
#             (kv): Linear(in_features=64, out_features=128, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=64, out_features=64, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (sr): Conv2d(64, 64, kernel_size=(4, 4), stride=(4, 4))
#             (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#           )
#           (drop_path): DropPath()
#           (norm2): LayerNorm((64,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=64, out_features=256, bias=True)
#             (dwconv): DWConv(
#               (dwconv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256)
#             )
#             (act): GELU()
#             (fc2): Linear(in_features=256, out_features=64, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (1): Block(
#           (norm1): LayerNorm((64,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention(
#             (q): Linear(in_features=64, out_features=64, bias=True)
#             (kv): Linear(in_features=64, out_features=128, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=64, out_features=64, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (sr): Conv2d(64, 64, kernel_size=(4, 4), stride=(4, 4))
#             (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#           )
#           (drop_path): DropPath()
#           (norm2): LayerNorm((64,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=64, out_features=256, bias=True)
#             (dwconv): DWConv(
#               (dwconv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256)
#             )
#             (act): GELU()
#             (fc2): Linear(in_features=256, out_features=64, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#       )
#       (norm2): LayerNorm((64,), eps=1e-06, elementwise_affine=True)
#       (block3): ModuleList(
#         (0): Block(
#           (norm1): LayerNorm((160,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention(
#             (q): Linear(in_features=160, out_features=160, bias=True)
#             (kv): Linear(in_features=160, out_features=320, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=160, out_features=160, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (sr): Conv2d(160, 160, kernel_size=(2, 2), stride=(2, 2))
#             (norm): LayerNorm((160,), eps=1e-05, elementwise_affine=True)
#           )
#           (drop_path): DropPath()
#           (norm2): LayerNorm((160,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=160, out_features=640, bias=True)
#             (dwconv): DWConv(
#               (dwconv): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=640)
#             )
#             (act): GELU()
#             (fc2): Linear(in_features=640, out_features=160, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (1): Block(
#           (norm1): LayerNorm((160,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention(
#             (q): Linear(in_features=160, out_features=160, bias=True)
#             (kv): Linear(in_features=160, out_features=320, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=160, out_features=160, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (sr): Conv2d(160, 160, kernel_size=(2, 2), stride=(2, 2))
#             (norm): LayerNorm((160,), eps=1e-05, elementwise_affine=True)
#           )
#           (drop_path): DropPath()
#           (norm2): LayerNorm((160,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=160, out_features=640, bias=True)
#             (dwconv): DWConv(
#               (dwconv): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=640)
#             )
#             (act): GELU()
#             (fc2): Linear(in_features=640, out_features=160, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#       )
#       (norm3): LayerNorm((160,), eps=1e-06, elementwise_affine=True)
#       (block4): ModuleList(
#         (0): Block(
#           (norm1): LayerNorm((256,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention(
#             (q): Linear(in_features=256, out_features=256, bias=True)
#             (kv): Linear(in_features=256, out_features=512, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=256, out_features=256, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath()
#           (norm2): LayerNorm((256,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=256, out_features=1024, bias=True)
#             (dwconv): DWConv(
#               (dwconv): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1024)
#             )
#             (act): GELU()
#             (fc2): Linear(in_features=1024, out_features=256, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (1): Block(
#           (norm1): LayerNorm((256,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention(
#             (q): Linear(in_features=256, out_features=256, bias=True)
#             (kv): Linear(in_features=256, out_features=512, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=256, out_features=256, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): DropPath()
#           (norm2): LayerNorm((256,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=256, out_features=1024, bias=True)
#             (dwconv): DWConv(
#               (dwconv): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1024)
#             )
#             (act): GELU()
#             (fc2): Linear(in_features=1024, out_features=256, bias=True)
#             (drop): Dropout(p=0.0, inplace=False)
#           )
#         )
#       )
#       (norm4): LayerNorm((256,), eps=1e-06, elementwise_affine=True)
#     )
#     (decode_head): SegFormerHead(
#       (linear_c4): MLP(
#         (proj): Linear(in_features=256, out_features=256, bias=True)
#       )
#       (linear_c3): MLP(
#         (proj): Linear(in_features=160, out_features=256, bias=True)
#       )
#       (linear_c2): MLP(
#         (proj): Linear(in_features=64, out_features=256, bias=True)
#       )
#       (linear_c1): MLP(
#         (proj): Linear(in_features=32, out_features=256, bias=True)
#       )
#       (linear_fuse): ConvModule(
#         (conv): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): ReLU(inplace=True)
#       )
#       (linear_pred): Conv2d(256, 1, kernel_size=(1, 1), stride=(1, 1))
#       (dropout): Dropout2d(p=0.1, inplace=False)
#     )
#   )
#   (dist_maps_base): DistMaps()
#   (dist_maps_refine): DistMaps()
#   (refiner): RefineLayer(
#     (image_conv1): ConvModule(
#       (conv): Conv2d(6, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activation): ReLU()
#     )
#     (image_conv2): XConvBnRelu(
#       (conv3x3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32)
#       (conv1x1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#       (norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activation): ReLU()
#     )
#     (image_conv3): XConvBnRelu(
#       (conv3x3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32)
#       (conv1x1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#       (norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activation): ReLU()
#     )
#     (refine_fusion): ConvModule(
#       (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1))
#       (norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activation): ReLU()
#     )
#     (refine_fusion2): XConvBnRelu(
#       (conv3x3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32)
#       (conv1x1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#       (norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activation): ReLU()
#     )
#     (refine_fusion3): XConvBnRelu(
#       (conv3x3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32)
#       (conv1x1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#       (norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activation): ReLU()
#     )
#     (feature_gate): Sequential(
#       (0): Conv2d(32, 1, kernel_size=(1, 1), stride=(1, 1))
#       (1): Sigmoid()
#     )
#     (refine_pred): Conv2d(32, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (refine_trimap): Conv2d(32, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
# )
# Model: isegm.model.is_segformer_model.SegFormerModel
# pipeline_version       = s2
# model_version          = b0
# use_leaky_relu         = True
# use_rgb_conv           = False
# use_disks              = True
# norm_radius            = 5
# binary_prev_mask       = False
# with_prev_mask         = True
# with_aux_output        = True
# feature_stride         = 4            (default)
# backbone_lr_mult       = 0.1          (default)
# norm_layer             = BatchNorm2d  (default)
# cpu_dist_maps          = False        (default)
# clicks_groups          = None         (default)
# conv_extend            = False        (default)
# norm_mean_std          = ([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]) (default)
#
# Starting Epoch: 0
# Total Epochs: 230
# 0%|                                                                        | 0/39 [00:00<?, ?it/s]
# /nfs/stak/users/wigginno/.local/lib/python3.9/site-packages/torch/optim/lr_scheduler.py:416: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# Epoch 0, training loss 1.4782:   0%|                                         | 0/39 [00:47<?, ?it/s]
# Epoch 0, training loss 1.5090:   5%|#6                               | 2/39 [00:55<13:18, 21.59s/it]
# Epoch 0, training loss 1.4264:  15%|#####                            | 6/39 [01:02<02:30,  4.55s/it]
# Epoch 0, training loss 1.3282:  26%|########2                       | 10/39 [01:08<01:01,  2.12s/it]
# Epoch 0, training loss 1.2803:  36%|###########4                    | 14/39 [01:14<00:43,  1.72s/it]
# Epoch 0, training loss 1.2540:  46%|##############7                 | 18/39 [01:20<00:36,  1.73s/it]
# Epoch 0, training loss 1.2331:  56%|##################              | 22/39 [01:27<00:26,  1.56s/it]
# Epoch 0, training loss 1.2228:  67%|#####################3          | 26/39 [01:34<00:21,  1.67s/it]
# Epoch 0, training loss 1.2146:  77%|########################6       | 30/39 [01:40<00:15,  1.71s/it]
# Epoch 0, training loss 1.2029:  87%|###########################8    | 34/39 [01:46<00:07,  1.42s/it]
# Epoch 0, training loss 1.1993:  95%|##############################3 | 37/39 [01:52<00:03,  1.68s/it]
# Save checkpoint to /nfs/hpc/share/wigginno/branching/ClickSEG/experiments/segformerB0_tubes/004_segformerB0_tubes/checkpoints/last_checkpoint.pth
# Save checkpoint to /nfs/hpc/share/wigginno/branching/ClickSEG/experiments/segformerB0_tubes/004_segformerB0_tubes/checkpoints/000.pth
# Epoch 1, training loss 1.2101:   0%|                                         | 0/39 [00:23<?, ?it/s]
# Epoch 1, training loss 1.1611:   8%|##5                              | 3/39 [00:30<04:18,  7.17s/it]
# Epoch 1, training loss 1.1502:  21%|######7                          | 8/39 [00:37<00:58,  1.88s/it]
# Epoch 1, training loss 1.1342:  33%|##########6                     | 13/39 [00:43<00:33,  1.29s/it]
# Epoch 1, training loss 1.1297:  44%|#############9                  | 17/39 [00:49<00:29,  1.34s/it]
# Epoch 1, training loss 1.1208:  54%|#################2              | 21/39 [00:56<00:28,  1.59s/it]
# Epoch 1, training loss 1.1147:  64%|####################5           | 25/39 [01:01<00:21,  1.52s/it]
# Epoch 1, training loss 1.1084:  74%|#######################7        | 29/39 [01:07<00:13,  1.37s/it]
# Epoch 1, training loss 1.1071:  82%|##########################2     | 32/39 [01:12<00:11,  1.57s/it]
# Epoch 1, training loss 1.1031:  90%|############################7   | 35/39 [01:17<00:06,  1.57s/it]
# Epoch 1, training loss 1.0957: 100%|################################| 39/39 [01:23<00:00,  2.13s/it]
# Save checkpoint to /nfs/hpc/share/wigginno/branching/ClickSEG/experiments/segformerB0_tubes/004_segformerB0_tubes/checkpoints/last_checkpoint.pth
# Epoch 2, training loss 1.0610:   0%|                                         | 0/39 [00:23<?, ?it/s]
# Epoch 2, training loss 1.0803:   5%|#6                               | 2/39 [00:28<07:25, 12.05s/it]
# Epoch 2, training loss 1.0667:  18%|#####9                           | 7/39 [00:34<01:13,  2.29s/it]
# Epoch 2, training loss 1.0546:  26%|########2                       | 10/39 [00:40<00:57,  1.97s/it]
# Epoch 2, training loss 1.0588:  33%|##########6                     | 13/39 [00:46<00:47,  1.84s/it]
# Epoch 2, training loss 1.0629:  44%|#############9                  | 17/39 [00:51<00:30,  1.38s/it]
# Epoch 2, training loss 1.0604:  54%|#################2              | 21/39 [00:57<00:24,  1.35s/it]
# Epoch 2, training loss 1.0589:  67%|#####################3          | 26/39 [01:03<00:17,  1.35s/it]
# Epoch 2, training loss 1.0577:  77%|########################6       | 30/39 [01:08<00:13,  1.53s/it]
# Epoch 2, training loss 1.0531:  87%|###########################8    | 34/39 [01:14<00:05,  1.18s/it]
# Epoch 2, training loss 1.0506:  95%|##############################3 | 37/39 [01:20<00:03,  1.60s/it]
# Save checkpoint to /nfs/hpc/share/wigginno/branching/ClickSEG/experiments/segformerB0_tubes/004_segformerB0_tubes/checkpoints/last_checkpoint.pth
# Epoch 3, training loss 0.9755:   0%|                                         | 0/39 [00:26<?, ?it/s]
# Epoch 3, training loss 1.0592:   8%|##5                              | 3/39 [00:31<04:31,  7.53s/it]
# Epoch 3, training loss 1.0378:  18%|#####9                           | 7/39 [00:37<01:18,  2.45s/it]
# Epoch 3, training loss 1.0421:  31%|#########8                      | 12/39 [00:43<00:35,  1.30s/it]
# Epoch 3, training loss 1.0352:  41%|#############1                  | 16/39 [00:50<00:35,  1.56s/it]
# Epoch 3, training loss 1.0328:  49%|###############5                | 19/39 [00:56<00:39,  1.98s/it]
# Epoch 3, training loss 1.0330:  56%|##################              | 22/39 [01:01<00:33,  2.00s/it]
# Epoch 3, training loss 1.0328:  67%|#####################3          | 26/39 [01:08<00:21,  1.66s/it]
# Epoch 3, training loss 1.0355:  77%|########################6       | 30/39 [01:14<00:15,  1.69s/it]
# Epoch 3, training loss 1.0330:  85%|###########################     | 33/39 [01:19<00:09,  1.55s/it]
# Epoch 3, training loss 1.0366:  95%|##############################3 | 37/39 [01:24<00:02,  1.38s/it]
# Save checkpoint to /nfs/hpc/share/wigginno/branching/ClickSEG/experiments/segformerB0_tubes/004_segformerB0_tubes/checkpoints/last_checkpoint.pth
# Epoch 4, training loss 0.9737:   0%|                                         | 0/39 [00:27<?, ?it/s]
# Epoch 4, training loss 1.0051:   8%|##5                              | 3/39 [00:34<04:50,  8.07s/it]
# Epoch 4, training loss 1.0127:  21%|######7                          | 8/39 [00:40<00:59,  1.93s/it]
# Epoch 4, training loss 1.0203:  28%|#########                       | 11/39 [00:46<00:50,  1.80s/it]
# Epoch 4, training loss 1.0212:  38%|############3                   | 15/39 [00:51<00:36,  1.51s/it]
# Epoch 4, training loss 1.0250:  51%|################4               | 20/39 [00:58<00:27,  1.45s/it]
# Epoch 4, training loss 1.0255:  62%|###################6            | 24/39 [01:06<00:23,  1.56s/it]
# Epoch 4, training loss 1.0221:  72%|######################9         | 28/39 [01:12<00:16,  1.51s/it]
# Epoch 4, training loss 1.0219:  85%|###########################     | 33/39 [01:18<00:07,  1.32s/it]
# Epoch 4, training loss 1.0233:  95%|##############################3 | 37/39 [01:23<00:02,  1.17s/it]
# Save checkpoint to /nfs/hpc/share/wigginno/branching/ClickSEG/experiments/segformerB0_tubes/004_segformerB0_tubes/checkpoints/last_checkpoint.pth
# Epoch 5, training loss 1.0175:   0%|                                         | 0/39 [00:25<?, ?it/s]
# Epoch 5, training loss 1.0062:   5%|#6                               | 2/39 [00:32<08:19, 13.50s/it]
# Epoch 5, training loss 1.0152:  15%|#####                            | 6/39 [00:38<01:39,  3.02s/it]
# Epoch 5, training loss 1.0188:  23%|#######6                         | 9/39 [00:44<01:05,  2.19s/it]
# Epoch 5, training loss 1.0257:  31%|#########8                      | 12/39 [00:50<00:56,  2.10s/it]
# Epoch 5, training loss 1.0206:  44%|#############9                  | 17/39 [00:56<00:27,  1.24s/it]
# Epoch 5, training loss 1.0135:  54%|#################2              | 21/39 [01:02<00:22,  1.25s/it]
# Epoch 5, training loss 1.0182:  64%|####################5           | 25/39 [01:08<00:20,  1.50s/it]
# Epoch 5, training loss 1.0169:  72%|######################9         | 28/39 [01:14<00:19,  1.77s/it]
# Epoch 5, training loss 1.0152:  82%|##########################2     | 32/39 [01:21<00:12,  1.73s/it]
# Epoch 5, training loss 1.0170:  95%|##############################3 | 37/39 [01:28<00:02,  1.34s/it]
# Save checkpoint to /nfs/hpc/share/wigginno/branching/ClickSEG/experiments/segformerB0_tubes/004_segformerB0_tubes/checkpoints/last_checkpoint.pth
# Epoch 6, training loss 0.9818:   0%|                                         | 0/39 [00:28<?, ?it/s]
# Epoch 6, training loss 0.9933:  10%|###3                             | 4/39 [00:34<02:56,  5.04s/it]
# Epoch 6, training loss 1.0101:  23%|#######6                         | 9/39 [00:41<00:51,  1.73s/it]
# Epoch 6, training loss 1.0186:  31%|#########8                      | 12/39 [00:47<00:49,  1.85s/it]
# Epoch 6, training loss 1.0129:  44%|#############9                  | 17/39 [00:52<00:29,  1.32s/it]
# Epoch 6, training loss 1.0105:  51%|################4               | 20/39 [00:58<00:29,  1.53s/it]
# Epoch 6, training loss 1.0130:  62%|###################6            | 24/39 [01:03<00:19,  1.27s/it]
# Epoch 6, training loss 1.0104:  74%|#######################7        | 29/39 [01:10<00:13,  1.33s/it]
# Epoch 6, training loss 1.0141:  85%|###########################     | 33/39 [01:16<00:08,  1.35s/it]
# Epoch 6, training loss 1.0156:  95%|##############################3 | 37/39 [01:22<00:03,  1.64s/it]
# Save checkpoint to /nfs/hpc/share/wigginno/branching/ClickSEG/experiments/segformerB0_tubes/004_segformerB0_tubes/checkpoints/last_checkpoint.pth
# Epoch 7, training loss 0.9676:   0%|                                         | 0/39 [00:26<?, ?it/s]
# Epoch 7, training loss 1.0024:   8%|##5                              | 3/39 [00:32<04:36,  7.69s/it]
# Epoch 7, training loss 0.9986:  18%|#####9                           | 7/39 [00:38<01:20,  2.52s/it]
# Epoch 7, training loss 1.0025:  28%|#########                       | 11/39 [00:44<00:44,  1.58s/it]
# Epoch 7, training loss 1.0022:  38%|############3                   | 15/39 [00:51<00:40,  1.70s/it]
# Epoch 7, training loss 1.0026:  46%|##############7                 | 18/39 [00:56<00:34,  1.65s/it]
# Epoch 7, training loss 1.0039:  54%|#################2              | 21/39 [01:02<00:33,  1.84s/it]
# Epoch 7, training loss 1.0087:  62%|###################6            | 24/39 [01:07<00:29,  1.99s/it]
# Epoch 7, training loss 1.0059:  72%|######################9         | 28/39 [01:13<00:18,  1.72s/it]
# Epoch 7, training loss 1.0069:  79%|#########################4      | 31/39 [01:19<00:14,  1.76s/it]
# Epoch 7, training loss 1.0091:  90%|############################7   | 35/39 [01:26<00:06,  1.71s/it]
# Save checkpoint to /nfs/hpc/share/wigginno/branching/ClickSEG/experiments/segformerB0_tubes/004_segformerB0_tubes/checkpoints/last_checkpoint.pth
# Epoch 8, training loss 0.9890:   0%|                                         | 0/39 [00:27<?, ?it/s]
# Epoch 8, training loss 1.0109:  10%|###3                             | 4/39 [00:32<02:48,  4.80s/it]
# Epoch 8, training loss 1.0098:  18%|#####9                           | 7/39 [00:38<01:16,  2.38s/it]
# Epoch 8, training loss 1.0090:  26%|########2                       | 10/39 [00:43<01:02,  2.17s/it]
# Epoch 8, training loss 1.0089:  36%|###########4                    | 14/39 [00:50<00:40,  1.63s/it]
# Epoch 8, training loss 1.0062:  44%|#############9                  | 17/39 [00:55<00:37,  1.70s/it]
# Epoch 8, training loss 1.0047:  51%|################4               | 20/39 [01:00<00:31,  1.68s/it]
# Epoch 8, training loss 1.0079:  62%|###################6            | 24/39 [01:07<00:25,  1.68s/it]
# Epoch 8, training loss 1.0103:  72%|######################9         | 28/39 [01:13<00:18,  1.65s/it]
# Epoch 8, training loss 1.0072:  79%|#########################4      | 31/39 [01:19<00:13,  1.64s/it]
# Epoch 8, training loss 1.0064:  87%|###########################8    | 34/39 [01:25<00:09,  1.88s/it]
# Epoch 8, training loss 1.0052:  95%|##############################3 | 37/39 [01:30<00:03,  1.96s/it]
# Save checkpoint to /nfs/hpc/share/wigginno/branching/ClickSEG/experiments/segformerB0_tubes/004_segformerB0_tubes/checkpoints/last_checkpoint.pth
# Epoch 9, training loss 1.0535:   0%|                                         | 0/39 [00:26<?, ?it/s]
# Epoch 9, training loss 1.0185:  10%|###3                             | 4/39 [00:32<02:53,  4.94s/it]
# Epoch 9, training loss 1.0059:  21%|######7                          | 8/39 [00:37<00:59,  1.92s/it]
# Epoch 9, training loss 1.0066:  28%|#########                       | 11/39 [00:43<00:47,  1.71s/it]
# Epoch 9, training loss 1.0102:  36%|###########4                    | 14/39 [00:48<00:42,  1.69s/it]
# ...
# Epoch 217, training loss 0.9714:  56%|################9             | 22/39 [01:03<00:26,  1.57s/it]
# Epoch 217, training loss 0.9701:  64%|###################2          | 25/39 [01:08<00:22,  1.59s/it]
# Epoch 217, training loss 0.9693:  74%|######################3       | 29/39 [01:15<00:13,  1.40s/it]
# Epoch 217, training loss 0.9698:  85%|#########################3    | 33/39 [01:21<00:09,  1.56s/it]
# Epoch 217, training loss 0.9689:  92%|###########################6  | 36/39 [01:26<00:04,  1.66s/it]
# Save checkpoint to /nfs/hpc/share/wigginno/branching/ClickSEG/experiments/segformerB0_tubes/004_segformerB0_tubes/checkpoints/last_checkpoint.pth
# Epoch 218, training loss 0.9582:   0%|                                       | 0/39 [00:25<?, ?it/s]
# Epoch 218, training loss 0.9637:   8%|##3                            | 3/39 [00:31<04:19,  7.21s/it]
# Epoch 218, training loss 0.9599:  15%|####7                          | 6/39 [00:37<01:45,  3.19s/it]
# Epoch 218, training loss 0.9608:  26%|#######6                      | 10/39 [00:43<00:51,  1.78s/it]
# Epoch 218, training loss 0.9621:  36%|##########7                   | 14/39 [00:49<00:40,  1.63s/it]
# Epoch 218, training loss 0.9636:  46%|#############8                | 18/39 [00:54<00:24,  1.19s/it]
# Epoch 218, training loss 0.9676:  56%|################9             | 22/39 [01:01<00:24,  1.44s/it]
# Epoch 218, training loss 0.9680:  67%|####################          | 26/39 [01:07<00:18,  1.39s/it]
# Epoch 218, training loss 0.9694:  74%|######################3       | 29/39 [01:13<00:16,  1.67s/it]
# Epoch 218, training loss 0.9682:  82%|########################6     | 32/39 [01:18<00:11,  1.63s/it]
# Epoch 218, training loss 0.9692:  92%|###########################6  | 36/39 [01:24<00:05,  1.73s/it]
# Save checkpoint to /nfs/hpc/share/wigginno/branching/ClickSEG/experiments/segformerB0_tubes/004_segformerB0_tubes/checkpoints/last_checkpoint.pth
# Epoch 219, training loss 1.0088:   0%|                                       | 0/39 [00:28<?, ?it/s]
# Epoch 219, training loss 0.9742:  10%|###1                           | 4/39 [00:36<03:09,  5.42s/it]
# Epoch 219, training loss 0.9766:  18%|#####5                         | 7/39 [00:41<01:40,  3.13s/it]
# Epoch 219, training loss 0.9780:  28%|########4                     | 11/39 [00:47<00:47,  1.70s/it]
# Epoch 219, training loss 0.9770:  36%|##########7                   | 14/39 [00:52<00:47,  1.89s/it]
# Epoch 219, training loss 0.9777:  46%|#############8                | 18/39 [00:58<00:30,  1.43s/it]
# Epoch 219, training loss 0.9769:  54%|################1             | 21/39 [01:03<00:27,  1.52s/it]
# Epoch 219, training loss 0.9755:  62%|##################4           | 24/39 [01:09<00:24,  1.63s/it]
# Epoch 219, training loss 0.9734:  72%|#####################5        | 28/39 [01:16<00:19,  1.75s/it]
# Epoch 219, training loss 0.9738:  85%|#########################3    | 33/39 [01:22<00:08,  1.39s/it]
# Epoch 219, training loss 0.9725:  95%|############################4 | 37/39 [01:28<00:03,  1.61s/it]
# Save checkpoint to /nfs/hpc/share/wigginno/branching/ClickSEG/experiments/segformerB0_tubes/004_segformerB0_tubes/checkpoints/last_checkpoint.pth
# Epoch 220, training loss 0.9628:   0%|                                       | 0/39 [00:25<?, ?it/s]
# Epoch 220, training loss 0.9643:   5%|#5                             | 2/39 [00:31<07:53, 12.80s/it]
# Epoch 220, training loss 0.9720:  13%|###9                           | 5/39 [00:37<02:28,  4.37s/it]
# Epoch 220, training loss 0.9700:  23%|#######1                       | 9/39 [00:43<01:06,  2.22s/it]
# Epoch 220, training loss 0.9655:  31%|#########2                    | 12/39 [00:49<00:53,  1.99s/it]
# Epoch 220, training loss 0.9640:  38%|###########5                  | 15/39 [00:55<00:46,  1.94s/it]
# Epoch 220, training loss 0.9626:  49%|##############6               | 19/39 [01:01<00:31,  1.59s/it]
# Epoch 220, training loss 0.9622:  59%|#################6            | 23/39 [01:07<00:21,  1.33s/it]
# Epoch 220, training loss 0.9647:  69%|####################7         | 27/39 [01:12<00:17,  1.42s/it]
# Epoch 220, training loss 0.9675:  79%|#######################8      | 31/39 [01:18<00:11,  1.43s/it]
# Epoch 220, training loss 0.9700:  92%|###########################6  | 36/39 [01:24<00:03,  1.18s/it]
# Save checkpoint to /nfs/hpc/share/wigginno/branching/ClickSEG/experiments/segformerB0_tubes/004_segformerB0_tubes/checkpoints/last_checkpoint.pth
# Save checkpoint to /nfs/hpc/share/wigginno/branching/ClickSEG/experiments/segformerB0_tubes/004_segformerB0_tubes/checkpoints/220.pth
# Epoch 221, training loss 0.9716:   0%|                                       | 0/39 [00:27<?, ?it/s]
# Epoch 221, training loss 0.9615:   8%|##3                            | 3/39 [00:33<04:28,  7.47s/it]
# Epoch 221, training loss 0.9624:  15%|####7                          | 6/39 [00:39<01:57,  3.56s/it]
# Epoch 221, training loss 0.9634:  26%|#######6                      | 10/39 [00:44<00:50,  1.76s/it]
# Epoch 221, training loss 0.9645:  36%|##########7                   | 14/39 [00:51<00:39,  1.57s/it]
# Epoch 221, training loss 0.9643:  44%|#############                 | 17/39 [00:57<00:41,  1.90s/it]
# Epoch 221, training loss 0.9644:  51%|###############3              | 20/39 [01:03<00:39,  2.10s/it]
# Epoch 221, training loss 0.9666:  64%|###################2          | 25/39 [01:09<00:21,  1.56s/it]
# Epoch 221, training loss 0.9665:  72%|#####################5        | 28/39 [01:15<00:17,  1.61s/it]
# Epoch 221, training loss 0.9687:  82%|########################6     | 32/39 [01:20<00:09,  1.35s/it]
# Epoch 221, training loss 0.9692:  92%|###########################6  | 36/39 [01:27<00:04,  1.38s/it]
# Save checkpoint to /nfs/hpc/share/wigginno/branching/ClickSEG/experiments/segformerB0_tubes/004_segformerB0_tubes/checkpoints/last_checkpoint.pth
# Epoch 222, training loss 0.9449:   0%|                                       | 0/39 [00:27<?, ?it/s]
# Epoch 222, training loss 0.9747:  10%|###1                           | 4/39 [00:33<02:51,  4.89s/it]
# Epoch 222, training loss 0.9732:  21%|######3                        | 8/39 [00:38<01:06,  2.16s/it]
# Epoch 222, training loss 0.9738:  31%|#########2                    | 12/39 [00:45<00:40,  1.51s/it]
# Epoch 222, training loss 0.9766:  44%|#############                 | 17/39 [00:51<00:29,  1.33s/it]
# Epoch 222, training loss 0.9766:  54%|################1             | 21/39 [00:57<00:25,  1.44s/it]
# Epoch 222, training loss 0.9749:  64%|###################2          | 25/39 [01:02<00:22,  1.60s/it]
# Epoch 222, training loss 0.9726:  72%|#####################5        | 28/39 [01:08<00:18,  1.72s/it]
# Epoch 222, training loss 0.9713:  82%|########################6     | 32/39 [01:14<00:10,  1.48s/it]
# Epoch 222, training loss 0.9710:  90%|##########################9   | 35/39 [01:20<00:07,  1.79s/it]
# Save checkpoint to /nfs/hpc/share/wigginno/branching/ClickSEG/experiments/segformerB0_tubes/004_segformerB0_tubes/checkpoints/last_checkpoint.pth
# Epoch 223, training loss 0.9559:   0%|                                       | 0/39 [00:29<?, ?it/s]
# Epoch 223, training loss 0.9658:   8%|##3                            | 3/39 [00:34<04:48,  8.01s/it]
# Epoch 223, training loss 0.9672:  18%|#####5                         | 7/39 [00:42<01:29,  2.79s/it]
# Epoch 223, training loss 0.9678:  26%|#######6                      | 10/39 [00:47<01:02,  2.17s/it]
# Epoch 223, training loss 0.9762:  36%|##########7                   | 14/39 [00:53<00:46,  1.87s/it]
# Epoch 223, training loss 0.9791:  46%|#############8                | 18/39 [00:59<00:29,  1.42s/it]
# Epoch 223, training loss 0.9794:  56%|################9             | 22/39 [01:05<00:23,  1.40s/it]
# Epoch 223, training loss 0.9766:  64%|###################2          | 25/39 [01:12<00:27,  1.93s/it]
# Epoch 223, training loss 0.9760:  72%|#####################5        | 28/39 [01:18<00:21,  1.98s/it]
# Epoch 223, training loss 0.9753:  82%|########################6     | 32/39 [01:23<00:09,  1.35s/it]
# Epoch 223, training loss 0.9753:  92%|###########################6  | 36/39 [01:29<00:04,  1.48s/it]
# Save checkpoint to /nfs/hpc/share/wigginno/branching/ClickSEG/experiments/segformerB0_tubes/004_segformerB0_tubes/checkpoints/last_checkpoint.pth
# Epoch 224, training loss 0.9794:   0%|                                       | 0/39 [00:31<?, ?it/s]
# Epoch 224, training loss 0.9690:  13%|###9                           | 5/39 [00:37<02:05,  3.68s/it]
# Epoch 224, training loss 0.9695:  23%|#######1                       | 9/39 [00:44<01:01,  2.06s/it]
# Epoch 224, training loss 0.9751:  33%|##########                    | 13/39 [00:49<00:36,  1.42s/it]
# Epoch 224, training loss 0.9752:  44%|#############                 | 17/39 [00:55<00:33,  1.53s/it]
# Epoch 224, training loss 0.9746:  54%|################1             | 21/39 [01:02<00:26,  1.47s/it]
# Epoch 224, training loss 0.9738:  64%|###################2          | 25/39 [01:08<00:19,  1.41s/it]
# Epoch 224, training loss 0.9737:  74%|######################3       | 29/39 [01:14<00:14,  1.47s/it]
# Epoch 224, training loss 0.9722:  85%|#########################3    | 33/39 [01:19<00:08,  1.48s/it]
# Epoch 224, training loss 0.9725:  95%|############################4 | 37/39 [01:25<00:02,  1.44s/it]
# Save checkpoint to /nfs/hpc/share/wigginno/branching/ClickSEG/experiments/segformerB0_tubes/004_segformerB0_tubes/checkpoints/last_checkpoint.pth
# Epoch 225, training loss 1.0021:   0%|                                       | 0/39 [00:30<?, ?it/s]
# Epoch 225, training loss 0.9825:   8%|##3                            | 3/39 [00:35<05:00,  8.34s/it]
# Epoch 225, training loss 0.9684:  15%|####7                          | 6/39 [00:41<01:56,  3.53s/it]
# Epoch 225, training loss 0.9706:  23%|#######1                       | 9/39 [00:47<01:14,  2.50s/it]
# Epoch 225, training loss 0.9709:  31%|#########2                    | 12/39 [00:52<00:51,  1.91s/it]
# Epoch 225, training loss 0.9746:  41%|############3                 | 16/39 [00:59<00:37,  1.63s/it]
# Epoch 225, training loss 0.9742:  51%|###############3              | 20/39 [01:04<00:32,  1.70s/it]
# Epoch 225, training loss 0.9761:  59%|#################6            | 23/39 [01:10<00:25,  1.62s/it]
# Epoch 225, training loss 0.9751:  67%|####################          | 26/39 [01:16<00:24,  1.87s/it]
# Epoch 225, training loss 0.9728:  74%|######################3       | 29/39 [01:22<00:20,  2.09s/it]
# Epoch 225, training loss 0.9717:  85%|#########################3    | 33/39 [01:27<00:08,  1.46s/it]
# Epoch 225, training loss 0.9723:  95%|############################4 | 37/39 [01:32<00:02,  1.37s/it]
# Save checkpoint to /nfs/hpc/share/wigginno/branching/ClickSEG/experiments/segformerB0_tubes/004_segformerB0_tubes/checkpoints/last_checkpoint.pth
# Save checkpoint to /nfs/hpc/share/wigginno/branching/ClickSEG/experiments/segformerB0_tubes/004_segformerB0_tubes/checkpoints/225.pth
# Epoch 226, training loss 0.9987:   0%|                                       | 0/39 [00:24<?, ?it/s]
# Epoch 226, training loss 0.9684:   5%|#5                             | 2/39 [00:29<06:47, 11.02s/it]
# Epoch 226, training loss 0.9616:  15%|####7                          | 6/39 [00:35<01:40,  3.04s/it]
# Epoch 226, training loss 0.9665:  28%|########4                     | 11/39 [00:41<00:37,  1.33s/it]
# Epoch 226, training loss 0.9664:  38%|###########5                  | 15/39 [00:48<00:33,  1.41s/it]
# Epoch 226, training loss 0.9680:  46%|#############8                | 18/39 [00:53<00:33,  1.58s/it]
# Epoch 226, training loss 0.9691:  56%|################9             | 22/39 [01:00<00:26,  1.57s/it]
# Epoch 226, training loss 0.9712:  67%|####################          | 26/39 [01:06<00:18,  1.42s/it]
# Epoch 226, training loss 0.9700:  74%|######################3       | 29/39 [01:12<00:18,  1.81s/it]
# Epoch 226, training loss 0.9692:  82%|########################6     | 32/39 [01:17<00:13,  1.94s/it]
# Epoch 226, training loss 0.9708:  92%|###########################6  | 36/39 [01:23<00:04,  1.57s/it]
# Save checkpoint to /nfs/hpc/share/wigginno/branching/ClickSEG/experiments/segformerB0_tubes/004_segformerB0_tubes/checkpoints/last_checkpoint.pth
# Epoch 227, training loss 0.9660:   0%|                                       | 0/39 [00:23<?, ?it/s]
# Epoch 227, training loss 0.9517:   5%|#5                             | 2/39 [00:31<06:43, 10.90s/it]
# Epoch 227, training loss 0.9710:  15%|####7                          | 6/39 [00:37<01:49,  3.31s/it]
# Epoch 227, training loss 0.9734:  26%|#######6                      | 10/39 [00:44<00:55,  1.92s/it]
# Epoch 227, training loss 0.9768:  33%|##########                    | 13/39 [00:49<00:48,  1.85s/it]
# Epoch 227, training loss 0.9739:  44%|#############                 | 17/39 [00:55<00:30,  1.41s/it]
# Epoch 227, training loss 0.9731:  54%|################1             | 21/39 [01:02<00:29,  1.62s/it]
# Epoch 227, training loss 0.9716:  62%|##################4           | 24/39 [01:07<00:25,  1.68s/it]
# Epoch 227, training loss 0.9709:  69%|####################7         | 27/39 [01:12<00:20,  1.70s/it]
# Epoch 227, training loss 0.9736:  82%|########################6     | 32/39 [01:18<00:09,  1.36s/it]
# Epoch 227, training loss 0.9727:  90%|##########################9   | 35/39 [01:23<00:05,  1.41s/it]
# Epoch 227, training loss 0.9722:  97%|#############################2| 38/39 [01:29<00:01,  1.62s/it]
# Save checkpoint to /nfs/hpc/share/wigginno/branching/ClickSEG/experiments/segformerB0_tubes/004_segformerB0_tubes/checkpoints/last_checkpoint.pth
# Epoch 228, training loss 0.9525:   0%|                                       | 0/39 [00:28<?, ?it/s]
# Epoch 228, training loss 0.9653:  10%|###1                           | 4/39 [00:34<02:58,  5.10s/it]
# Epoch 228, training loss 0.9647:  18%|#####5                         | 7/39 [00:39<01:23,  2.62s/it]
# Epoch 228, training loss 0.9714:  26%|#######6                      | 10/39 [00:44<01:00,  2.09s/it]
# Epoch 228, training loss 0.9732:  38%|###########5                  | 15/39 [00:51<00:34,  1.42s/it]
# Epoch 228, training loss 0.9734:  51%|###############3              | 20/39 [00:57<00:24,  1.32s/it]
# Epoch 228, training loss 0.9738:  62%|##################4           | 24/39 [01:03<00:23,  1.55s/it]
# Epoch 228, training loss 0.9739:  69%|####################7         | 27/39 [01:09<00:18,  1.57s/it]
# Epoch 228, training loss 0.9754:  79%|#######################8      | 31/39 [01:14<00:11,  1.43s/it]
# Epoch 228, training loss 0.9766:  90%|##########################9   | 35/39 [01:20<00:06,  1.63s/it]
# Epoch 228, training loss 0.9757: 100%|##############################| 39/39 [01:25<00:00,  2.19s/it]
# Save checkpoint to /nfs/hpc/share/wigginno/branching/ClickSEG/experiments/segformerB0_tubes/004_segformerB0_tubes/checkpoints/last_checkpoint.pth
# Epoch 229, training loss 0.9402:   0%|                                       | 0/39 [00:32<?, ?it/s]
# Epoch 229, training loss 0.9622:  10%|###1                           | 4/39 [00:38<03:24,  5.85s/it]
# Epoch 229, training loss 0.9657:  18%|#####5                         | 7/39 [00:44<01:33,  2.91s/it]
# Epoch 229, training loss 0.9699:  31%|#########2                    | 12/39 [00:50<00:41,  1.55s/it]
# Epoch 229, training loss 0.9694:  44%|#############                 | 17/39 [00:56<00:27,  1.27s/it]
# Epoch 229, training loss 0.9681:  54%|################1             | 21/39 [01:03<00:28,  1.56s/it]
# Epoch 229, training loss 0.9688:  67%|####################          | 26/39 [01:10<00:17,  1.33s/it]
# Epoch 229, training loss 0.9678:  77%|#######################       | 30/39 [01:17<00:14,  1.58s/it]
# Epoch 229, training loss 0.9676:  85%|#########################3    | 33/39 [01:22<00:10,  1.68s/it]
# Epoch 229, training loss 0.9684:  95%|############################4 | 37/39 [01:28<00:03,  1.67s/it]
# Save checkpoint to /nfs/hpc/share/wigginno/branching/ClickSEG/experiments/segformerB0_tubes/004_segformerB0_tubes/checkpoints/last_checkpoint.pth

# %%
# start time: 4:30pm
# end time:
